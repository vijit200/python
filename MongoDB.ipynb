# %%
# !pip install pymongo
# !pip install pymongo[srv]

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb+srv://test:test@cluster0.lrc1y.mongodb.net/myFirstDatabase?retryWrites=true&w=majority',tls = True,tlsAllowInvalidCertificates= True)

# %%
db = client["vijit"]

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'test2',
#  'viji',
#  'admin',
#  'local']

# %%
# in case mysql table ,and record & rows is created
# in case of mongo is  collection and documents

# %%
col1 =db["iNeuron_collection"]

# %%
import flask 
from flask import Flask
app = Flask(__name__)
@app.route("/viji",methods = ['GET'])
def name():

    return '''<h1>my result is : {}</h1>'''

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
dict1 = {
    "name":"viji",
    "ermail":"vnlfn@bmcl",
    "phno":46846664
}

# %%
col1.insert_one(dict1)

# %%
# !pip install dnspython #if any error occur
# Out:
# ERROR: Invalid requirement: '#if'

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb+srv://test:test@cluster0.lrc1y.mongodb.net/myFirstDatabase?retryWrites=true&w=majority',tls = True,tlsAllowInvalidCertificates = True)

# %%
client
# Out:
# MongoClient(host=['cluster0-shard-00-02.lrc1y.mongodb.net:27017', 'cluster0-shard-00-01.lrc1y.mongodb.net:27017', 'cluster0-shard-00-00.lrc1y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-ahjyy4-shard-0', tls=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True)

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'test2',
#  'viji',
#  'vijit',
#  'admin',
#  'local']

# %%
db = client['test3']

# %%
col1 = db['table']

# %%
list1 = [
        {
            "item": "canvas",
            "qty": 100,
            "size": {"h": 28, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "journal",
            "qty": 25,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mat",
            "qty": 85,
            "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mousepad",
            "qty": 25,
            "size": {"h": 19, "w": 22.85, "uom": "cm"},
            "status": "P",
        },
        {
            "item": "notebook",
            "qty": 50,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "P",
        },
        {
            "item": "paper",
            "qty": 100,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "D",
        },
        {
            "item": "planner",
            "qty": 75,
            "size": {"h": 22.85, "w": 30, "uom": "cm"},
            "status": "D",
        },
        {
            "item": "postcard",
            "qty": 45,
            "size": {"h": 10, "w": 15.25, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketchbook",
            "qty": 80,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketch pad",
            "qty": 95,
            "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
            "status": "A",
        },
    ]

# %%
col1.insert_many(list1)

# %%
for i in col1.find():
    print(i)
# Out:
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a2'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a3'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a4'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a5'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a6'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a7'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a8'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# ...

# %%
for i in  col1.find({'qty':{'$gt':45}}):
    print(i)
# Out:
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a2'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a4'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a6'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a7'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44a8'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44aa'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('6210809bbbbcb7b5c57b44ab'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}

# %%
col1.update_many({'qty': {"$gt" : 50}} , {"$set" :{'qty' : 400}})

# %%
import pandas as pd

# %%
df = pd.read_csv('car-Copy1.csv')

# %%
df.to_json('car.json')

# %%
db1 = client['car']
col2 = db1['car_col']

# %%
import json
tweet = []
for line in open('car.json','r'):
    tweet.append(json.loads(line))

# %%
tweet
# Out:
# [{'0': {'0': 'vhigh',
#    '1': 'vhigh',
#    '2': 'vhigh',
#    '3': 'vhigh',
#    '4': 'vhigh',
#    '5': 'vhigh',
#    '6': 'vhigh',
#    '7': 'vhigh',
#    '8': 'vhigh',
#    '9': 'vhigh',
#    '10': 'vhigh',
#    '11': 'vhigh',
#    '12': 'vhigh',
#    '13': 'vhigh',
#    '14': 'vhigh',
#    '15': 'vhigh',
#    '16': 'vhigh',
#    '17': 'vhigh',
#    '18': 'vhigh',
#    '19': 'vhigh',
#    '20': 'vhigh',
#    '21': 'vhigh',
#    '22': 'vhigh',
#    '23': 'vhigh',
#    '24': 'vhigh',
#    '25': 'vhigh',
#    '26': 'vhigh',
#    '27': 'vhigh',
#    '28': 'vhigh',
#    '29': 'vhigh',
#    '30': 'vhigh',
#    '31': 'vhigh',
#    '32': 'vhigh',
#    '33': 'vhigh',
#    '34': 'vhigh',
#    '35': 'vhigh',
#    '36': 'vhigh',
#    '37': 'vhigh',
#    '38': 'vhigh',
#    '39': 'vhigh',
#    '40': 'vhigh',
#    '41': 'vhigh',
#    '42': 'vhigh',
#    '43': 'vhigh',
#    '44': 'vhigh',
#    '45': 'vhigh',
#    '46': 'vhigh',
#    '47': 'vhigh',
#    '48': 'vhigh',
#    '49': 'vhigh',
# ...

# %%
col2.insert_many(tweet)

# %%
# Out:
# 152091

# %%
col3 = db1['car_col2']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\VIJITK~1\AppData\Local\Temp/ipykernel_14296/2815665889.py in <module>
# ----> 1 col3.insert_many(l[0])
#
# ~\.conda\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     586         write_concern = self._write_concern_for(session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 588         blk.ops = [doc for doc in gen()]
#     589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~\.conda\lib\site-packages\pymongo\collection.py in <listcomp>(.0)
#     586         write_concern = self._write_concern_for(session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 588         blk.ops = [doc for doc in gen()]
# ...

# %%
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
pd.read_json('car.json')
# Out:
#           0      1      2     3      4     5      6
# 0     vhigh  vhigh      2     2  small   low  unacc
# 1     vhigh  vhigh      2     2  small   med  unacc
# 2     vhigh  vhigh      2     2  small  high  unacc
# 3     vhigh  vhigh      2     2    med   low  unacc
# 4     vhigh  vhigh      2     2    med   med  unacc
# ...     ...    ...    ...   ...    ...   ...    ...
# 1723    low    low  5more  more    med   med   good
# 1724    low    low  5more  more    med  high  vgood
# 1725    low    low  5more  more    big   low  unacc
# 1726    low    low  5more  more    big   med   good
# 1727    low    low  5more  more    big  high  vgood
#
# [1728 rows x 7 columns]

# %%
c = list(col1.find())

# %%
pd.DataFrame(c)
# Out:
#                         _id        item  qty  \
# 0  6210809bbbbcb7b5c57b44a2      canvas  400
# 1  6210809bbbbcb7b5c57b44a3     journal   25
# 2  6210809bbbbcb7b5c57b44a4         mat  400
# 3  6210809bbbbcb7b5c57b44a5    mousepad   25
# 4  6210809bbbbcb7b5c57b44a6    notebook   50
# 5  6210809bbbbcb7b5c57b44a7       paper  400
# 6  6210809bbbbcb7b5c57b44a8     planner  400
# 7  6210809bbbbcb7b5c57b44a9    postcard   45
# 8  6210809bbbbcb7b5c57b44aa  sketchbook  400
# 9  6210809bbbbcb7b5c57b44ab  sketch pad  400
#
#                                    size status
# 0     {'h': 28, 'w': 35.5, 'uom': 'cm'}      A
# 1       {'h': 14, 'w': 21, 'uom': 'cm'}      A
# 2   {'h': 27.9, 'w': 35.5, 'uom': 'cm'}      A
# 3    {'h': 19, 'w': 22.85, 'uom': 'cm'}      P
# 4      {'h': 8.5, 'w': 11, 'uom': 'in'}      P
# 5      {'h': 8.5, 'w': 11, 'uom': 'in'}      D
# 6    {'h': 22.85, 'w': 30, 'uom': 'cm'}      D
# 7    {'h': 10, 'w': 15.25, 'uom': 'cm'}      A
# ...

# %%
l = df.to_dict(orient='records')#use to convert data into json

# %%
l
# Out:
# [{'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'small',
#   '5': 'low',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'small',
#   '5': 'med',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'small',
#   '5': 'high',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'med',
#   '5': 'low',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'med',
#   '5': 'med',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'med',
#   '5': 'high',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'big',
#   '5': 'low',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
#   '4': 'big',
#   '5': 'med',
#   '6': 'unacc'},
#  {'0': 'vhigh',
#   '1': 'vhigh',
#   '2': '2',
#   '3': '2',
# ...

# %%
db2 = client['car_data']
col = db2['car_col']
col.insert_many(l)
