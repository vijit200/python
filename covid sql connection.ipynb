# %% [markdown]
# # Inserting LIB

# %%
import csv
import pandas as pd 
import mysql.connector as conn

# %% [markdown]
# # Converting CSV into DataFrame

# %%
df = pd.read_csv("covid-variants.csv",index_col=False,delimiter=",")

# %%
df.head()
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %% [markdown]
# # Creating Connection & Database

# %%
from mysql.connector import errors

# %%
try:
    mydb = conn.connect(host ="localhost",user = "root", passwd = "Vijit699@")
    if mydb.is_connected():
        cur = mydb.cursor()
        cur.execute("CREATE DATABASE IF NOT EXISTS covid")
except Exception as e:
    print(e)

# %% [markdown]
# # Creating Table & Inserting Values

# %%
cur.execute("CREATE TABLE covid.covid_2020(Location VARCHAR(25),Date DATE,Variant VARCHAR(25),Num_seq INT(10),Prec_seq FLOAT(10,5),Num_seq_prec INT(10))")

# %%
try:
    for i ,row in df.iterrows():
        sql ="INSERT INTO covid.covid_2020 VALUES(%s,%s,%s,%s,%s,%s)"
        cur.execute(sql,tuple(row))
        print("inserted")
        mydb.commit()
except Exception as e:
    print(e)
# Out:
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# ...
