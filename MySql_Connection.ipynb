# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost" , user = "root" , passwd = "Vijit699@" ,use_pure = True)

# %%
mydb.is_connected()
# Out:
# True

# %%
query = "SHOW DATABASEs"
cur = mydb.cursor()
cur.execute(query)
c = cur.fetchall()

# %%
c
# Out:
# [('bank_detail',),
#  ('carbon_nanotubes',),
#  ('carbon_tubes',),
#  ('employees',),
#  ('information',),
#  ('information_schema',),
#  ('infotmation',),
#  ('mysql',),
#  ('performance_schema',),
#  ('persons_information',),
#  ('sakila',),
#  ('sales',),
#  ('sys',),
#  ('testviji',),
#  ('vijitkumar200',),
#  ('vijitkumar201',),
#  ('vijitkumar202',),
#  ('vijitkumar203',),
#  ('world',)]

# %%
for i in c:
    print(i[0])
# Out:
# bank_detail
# carbon_nanotubes
# carbon_tubes
# employees
# information
# information_schema
# infotmation
# mysql
# performance_schema
# persons_information
# sakila
# sales
# sys
# testviji
# vijitkumar200
# vijitkumar201
# vijitkumar202
# vijitkumar203
# world

# %%
cur = mydb.cursor()
cur.execute("CREATE DATABASE IF NOT EXISTS testviji")

# %%
cur.execute("CREATE TABLE testviji.INeuron(student_id INT(10),First_name VARCHAR(20),Last_name VARCHAR(20),Registration_id INT(10),ClassName VARCHAR(20))")

# %%
cur.execute("SHOW TABLES FROM testviji")

# %%
cur.fetchall()
# Out:
# [('ineuron',)]

# %%
cur.execute("SHOW COLUMNS FROM testviji.INeuron")

# %%
cur.fetchall()
# Out:
# [('student_id', b'int', 'YES', '', None, ''),
#  ('First_name', b'varchar(20)', 'YES', '', None, ''),
#  ('Last_name', b'varchar(20)', 'YES', '', None, ''),
#  ('Registration_id', b'int', 'YES', '', None, ''),
#  ('ClassName', b'varchar(20)', 'YES', '', None, '')]

# %%
cur.execute("SELECT * FROM testviji.INeuron")

# %%
cur.execute("INSERT INTO testviji.INeuron VALUES(454223,'Henil' ,'Pal', 424256,'FSDS')")

# %%
cur.execute("commit")

# %%
cur.fetchall()
# Out:
# [(45421, 'vijit', 'kumar', 42424, 'Mysql'),
#  (45422, 'Monika', 'Pal', 42425, 'FSDS'),
#  (454223, 'Henil', 'Pal', 424256, 'FSDS')]

# %%
cur.execute("CREATE TABLE testviji.glassData (col1 INT(10),col2 FLOAT(10,5),col3 FLOAT(10,5),col4 FLOAT(10,5),col5 FLOAT(10,5),col6 FLOAT(10,5),col7 FLOAT(10,5),col8 FLOAT(10,5),col9 FLOAT(10,5),col10 FLOAT(10,5),col11 INT(10) )")

# %%
cur.execute("SHOW TABLES FROM testviji")

# %%
cur.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
import csv
with open("glass.data","r") as data:
    d = csv.reader(data , delimiter = "\n")
    for i in d:
        cur.execute("insert into testviji.glassdata values({d})".format(d = i[0]))
        cur.execute("commit")

# %%
cur.execute("insert into testviji.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)")

# %%
cur.execute("commit")

# %%
import pandas as pd

# %%
pd.read_sql("select * from testviji.glassdata",mydb)
# Out:
#      col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 2       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 3       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 4       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 210   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# 211   211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.0      7
# 212   212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.0      7
# 213   213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.0      7
# 214   214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.0      7
#
# [215 rows x 11 columns]

# %%
pd.read_sql("show databases",mydb)
# Out:
#                Database
# 0           bank_detail
# 1      carbon_nanotubes
# 2          carbon_tubes
# 3             employees
# 4           information
# 5    information_schema
# 6           infotmation
# 7                 mysql
# 8    performance_schema
# 9   persons_information
# 10               sakila
# 11                sales
# 12                  sys
# 13             testviji
# 14        vijitkumar200
# 15        vijitkumar201
# 16        vijitkumar202
# 17        vijitkumar203
# 18                world

# %%
import mysql.connector as conn
mydb = conn.connect(host = "localhost" , user = "root", passwd = "Vijit699@")

# %%
cur = mydb.cursor()

# %%
cur.execute("SHOW DATABASES")
cur.fetchall()
# Out:
# [('bank_detail',),
#  ('carbon_nanotubes',),
#  ('carbon_tubes',),
#  ('data',),
#  ('employees',),
#  ('information',),
#  ('information_schema',),
#  ('infotmation',),
#  ('mysql',),
#  ('performance_schema',),
#  ('persons_information',),
#  ('sakila',),
#  ('sales',),
#  ('sync_mach',),
#  ('syncmach',),
#  ('sys',),
#  ('testviji',),
#  ('vijitkumar200',),
#  ('vijitkumar201',),
#  ('vijitkumar202',),
#  ('vijitkumar203',),
#  ('world',)]

# %%
cur.execute("SHOW TABLES FROM testviji")

# %%
cur.fetchall()
# Out:
# [('amazo',), ('amazon',), ('glassdata',), ('ineuron',), ('sy',)]

# %%
cur.execute("SELECT * FROM testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
# ...

# %%
cur.execute("SELECT col1 , col3, col5 FROM testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [(1, 13.64, 1.1),
#  (1, 13.64, 1.1),
#  (2, 13.89, 1.36),
#  (3, 13.53, 1.54),
#  (4, 13.21, 1.29),
#  (5, 13.27, 1.24),
#  (6, 12.79, 1.62),
#  (7, 13.3, 1.14),
#  (8, 13.15, 1.05),
#  (9, 14.04, 1.37),
#  (10, 13.0, 1.36),
#  (11, 12.72, 1.56),
#  (12, 12.8, 1.27),
#  (13, 12.88, 1.4),
#  (14, 12.86, 1.27),
#  (15, 12.61, 1.31),
#  (16, 12.81, 1.23),
#  (17, 12.68, 1.16),
#  (18, 14.36, 0.89),
#  (19, 13.9, 1.18),
#  (20, 13.02, 1.69),
#  (21, 12.82, 1.49),
#  (22, 14.77, 0.29),
#  (23, 12.78, 1.29),
#  (24, 12.81, 1.35),
#  (25, 13.38, 1.15),
#  (26, 12.98, 1.21),
#  (27, 13.21, 1.41),
#  (28, 12.87, 1.33),
#  (29, 12.56, 1.43),
#  (30, 13.08, 1.28),
#  (31, 12.65, 1.3),
#  (32, 12.84, 1.14),
#  (33, 12.85, 1.23),
#  (34, 12.57, 1.38),
#  (35, 12.69, 1.34),
#  (36, 13.29, 1.21),
#  (37, 13.89, 1.32),
#  (38, 12.74, 1.35),
#  (39, 14.21, 0.47),
#  (40, 14.21, 0.47),
#  (41, 12.79, 1.12),
#  (42, 12.71, 1.2),
#  (43, 13.21, 1.33),
#  (44, 13.73, 0.72),
#  (45, 12.73, 1.19),
# ...

# %%
cur.execute("show columns from testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [('col1', b'int', 'YES', '', None, ''),
#  ('col2', b'float(10,5)', 'YES', '', None, ''),
#  ('col3', b'float(10,5)', 'YES', '', None, ''),
#  ('col4', b'float(10,5)', 'YES', '', None, ''),
#  ('col5', b'float(10,5)', 'YES', '', None, ''),
#  ('col6', b'float(10,5)', 'YES', '', None, ''),
#  ('col7', b'float(10,5)', 'YES', '', None, ''),
#  ('col8', b'float(10,5)', 'YES', '', None, ''),
#  ('col9', b'float(10,5)', 'YES', '', None, ''),
#  ('col10', b'float(10,5)', 'YES', '', None, ''),
#  ('col11', b'int', 'YES', '', None, '')]

# %%
cur.execute("SELECT * FROM testviji.glassdata WHERE col1 = 4 AND col11 = 1")

# %%
cur.fetchall()
# Out:
# [(4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1)]

# %%
cur.execute("DELETE FROM testviji.glassdata WHERE col1 = 4")

# %%
cur.execute("SELECT * FROM testviji.glassdata")

# %%
b = cur.fetchall()

# %%
b
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
for i in b:
    if i[0] == 3 and i[10] == 1:
        print(i)
# Out:
# (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1)

# %%
mydb.commit()

# %%
cur.execute("UPDATE testviji.glassdata SET col1 = 6 ,col2 = 8 WHERE col1 = 3")

# %%
cur.execute("commit")

# %%
cur.execute("SELECT * FROM testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (6, 8.0, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cur.execute("SELECT count(col1), col2 FROM testviji.glassdata GROUP BY col1")

# %%
cur.fetchall()
# Out:
# [(2, 1.52101),
#  (1, 1.51761),
#  (2, 8.0),
#  (1, 1.51742),
#  (1, 1.51743),
#  (1, 1.51756),
#  (1, 1.51918),
#  (1, 1.51755),
#  (1, 1.51571),
#  (1, 1.51763),
#  (1, 1.51589),
#  (1, 1.51748),
#  (1, 1.51763),
#  (1, 1.51761),
#  (1, 1.51784),
#  (1, 1.52196),
#  (1, 1.51911),
#  (1, 1.51735),
#  (1, 1.5175),
#  (1, 1.51966),
#  (1, 1.51736),
#  (1, 1.51751),
#  (1, 1.5172),
#  (1, 1.51764),
#  (1, 1.51793),
#  (1, 1.51721),
#  (1, 1.51768),
#  (1, 1.51784),
#  (1, 1.51768),
#  (1, 1.51747),
#  (1, 1.51775),
#  (1, 1.51753),
#  (1, 1.51783),
#  (1, 1.51567),
#  (1, 1.51909),
#  (1, 1.51797),
#  (1, 1.52213),
#  (1, 1.52213),
#  (1, 1.51793),
#  (1, 1.51755),
#  (1, 1.51779),
#  (1, 1.5221),
#  (1, 1.51786),
#  (1, 1.519),
#  (1, 1.51869),
#  (1, 1.52667),
#  (1, 1.52223),
#  (1, 1.51898),
#  (1, 1.5232),
#  (1, 1.51926),
#  (1, 1.51808),
#  (1, 1.51837),
#  (1, 1.51778),
#  (1, 1.51769),
#  (1, 1.51215),
#  (1, 1.51824),
#  (1, 1.51754),
#  (1, 1.51754),
#  (1, 1.51905),
# ...

# %%
cur.execute("SELECT * FROM testviji.glassdata WHERE col1 = 6")

# %%
cur.fetchall()
# Out:
# [(6, 8.0, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cur.execute("select col1 , count(col1) , col11 from testviji.glassdata group by col1")

# %%
cur.fetchall()
# Out:
# [(1, 2, 1),
#  (2, 1, 1),
#  (6, 2, 1),
#  (5, 1, 1),
#  (7, 1, 1),
#  (8, 1, 1),
#  (9, 1, 1),
#  (10, 1, 1),
#  (11, 1, 1),
#  (12, 1, 1),
#  (13, 1, 1),
#  (14, 1, 1),
#  (15, 1, 1),
#  (16, 1, 1),
#  (17, 1, 1),
#  (18, 1, 1),
#  (19, 1, 1),
#  (20, 1, 1),
#  (21, 1, 1),
#  (22, 1, 1),
#  (23, 1, 1),
#  (24, 1, 1),
#  (25, 1, 1),
#  (26, 1, 1),
#  (27, 1, 1),
#  (28, 1, 1),
#  (29, 1, 1),
#  (30, 1, 1),
#  (31, 1, 1),
#  (32, 1, 1),
#  (33, 1, 1),
#  (34, 1, 1),
#  (35, 1, 1),
#  (36, 1, 1),
#  (37, 1, 1),
#  (38, 1, 1),
#  (39, 1, 1),
#  (40, 1, 1),
#  (41, 1, 1),
#  (42, 1, 1),
#  (43, 1, 1),
#  (44, 1, 1),
#  (45, 1, 1),
#  (46, 1, 1),
#  (47, 1, 1),
#  (48, 1, 1),
#  (49, 1, 1),
#  (50, 1, 1),
#  (51, 1, 1),
#  (52, 1, 1),
#  (53, 1, 1),
#  (54, 1, 1),
#  (55, 1, 1),
#  (56, 1, 1),
#  (57, 1, 1),
#  (58, 1, 1),
#  (59, 1, 1),
#  (60, 1, 1),
#  (61, 1, 1),
#  (62, 1, 1),
#  (63, 1, 1),
#  (64, 1, 1),
#  (65, 1, 1),
#  (66, 1, 1),
#  (67, 1, 1),
#  (68, 1, 1),
#  (69, 1, 1),
# ...

# %%
cur.execute("select * from testviji.ineuron")

# %%
cur.fetchall()
# Out:
# [(45421, 'vijit', 'kumar', 42424, 'Mysql'),
#  (45422, 'Monika', 'Pal', 42425, 'FSDS'),
#  (454223, 'Henil', 'Pal', 424256, 'FSDS')]

# %%
cur.execute("select count(*) from testviji.ineuron where ClassName = 'FSDS'")

# %%
cur.execute("show columns from testviji.ineuron")

# %%
cur.fetchall()
# Out:
# [('student_id', b'int', 'YES', '', None, ''),
#  ('First_name', b'varchar(20)', 'YES', '', None, ''),
#  ('Last_name', b'varchar(20)', 'YES', '', None, ''),
#  ('Registration_id', b'int', 'YES', '', None, ''),
#  ('ClassName', b'varchar(20)', 'YES', '', None, '')]

# %%
cur.execute("select count(*) ,student_id from testviji.ineuron group by student_id")

# %%
cur.fetchall()
# Out:
# [(1, 45421), (1, 45422), (1, 454223)]

# %%
cur.execute("DROP TABLE testviji.sy")

# %%
mydb.commit()

# %%
cur.execute("SHOW TABLES from testviji")

# %%
cur.fetchall()
# Out:
# [('amazo',), ('amazon',), ('glassdata',), ('ineuron',)]

# %%
cur.execute("SELECT * FROM testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (6, 8.0, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cur.execute("SELECT col1 , col2, col11 FROM testviji.glassdata WHERE col1 =11 or col11 = 2")

# %%
cur.fetchall()
# Out:
# [(11, 1.51571, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %%
cur.execute("SELECT col1 , col2, col11 FROM testviji.glassdata WHERE col1 =11 AND col11 = 2")

# %%
cur.fetchall()
# Out:
# []

# %%
cur.execute("SELECT * FROM testviji.glassdata WHERE col2 like('%.51%')")

# %%
cur.fetchall()
# Out:
# [(2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
#  (17, 1.51784, 12.68, 3.67, 1.16, 73.11, 0.61, 8.7, 0.0, 0.0, 1),
# ...

# %%
cur.execute("select * from testviji.glassdata")

# %%
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (6, 8.0, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cur.execute("select * from testviji.glassdata WHERE  col1 > 112 AND col11 = 3 order by col2 DESC")

# %%
cur.fetchall()
# Out:
# [(163, 1.52211, 14.19, 3.78, 0.91, 71.36, 0.23, 9.14, 0.0, 0.37, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (162, 1.51934, 13.64, 3.54, 0.75, 72.65, 0.16, 8.89, 0.15, 0.24, 3),
#  (161, 1.51832, 13.33, 3.34, 1.54, 72.14, 0.56, 8.99, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
# ...

# %%
cur.execute("select * from (select * from testviji.glassdata WHERE  col1 > 112) as v where col11 = 3")

# %%
cur.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cur.execute("select * from testviji.glassdata group by col1 having count(col1)>1")

# %%
cur.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1)]

# %% [raw]
# for inserting data in bulk with csv file im MySQL
#
# df = pd.read_csv("covid-variants.csv",index_col=False,delimiter=",")
# try:
#     for i ,row in df.iterrows():
#         sql ="INSERT INTO covid.covid_2020 VALUES(%s,%s,%s,%s,%s,%s)"
#         cur.execute(sql,tuple(row))
#         print("inserted")
#         mydb.commit()
# except Exception as e:
#     print(e)
