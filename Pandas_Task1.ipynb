# %% [raw]
# For titanic datset :
#
#
# 1 . Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [raw]
# 1 . Find out how many male and female passenger was onboarded .

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
print(len(df[df['Sex'] == 'male']),'male')
print(len(df[df['Sex'] == 'female']),'female')
# Out:
# 577 male
# 314 female

# %% [raw]
# 2. how many survived we have

# %%
print(len(df[df['Survived'] == 1]),'Survived')
# Out:
# 342 Survived

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %% [raw]
# 3. how many casuality we have

# %%
print(len(df[df['Survived'] == 0]),'Casuality')
# Out:
# 549 Casuality

# %% [raw]
# 4 . what is name of a person who is the eldest one

# %%
print(df[df['Age'] == max(df['Age'])]['Name'])
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df[df['Age'] == df['Age'].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [raw]
# 5 . how many passenger do we have in first , second and third class

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
print(len(df[df['Pclass'] == 1]),'class1')
print(len(df[df['Pclass'] == 2]),'class2')
print(len(df[df['Pclass'] == 3]),'class3')
# Out:
# 216 class1
# 184 class2
# 491 class3

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %% [raw]
# 6. how many person we have whose name starts with "s"

# %%
l = []
for i in df['Name']:
    if i[0] == 'S':
        l.append(i)
len(l)
# Out:
# 86

# %%
len(df[df['Name'].str.startswith('S')])
# Out:
# 86

# %% [raw]
# 7. try to create a new column which is a summation  of "SibSp" and "parch"

# %%
df['sumofSibsp'] = df['SibSp']+df['Parch']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sumofSibsp
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      0            113803  53.1000  C123        S           1
# 4      0            373450   8.0500   NaN        S           0

# %% [raw]
# 8 . how many person do we have below age of 25

# %%
print(len(df[df['Age']<25]))
# Out:
# 278

# %% [raw]
# 9 . how many person died whose age was less then 40

# %%
a = df[df['Survived']==0]
b = a[a['Age']<40]
print(b.shape)
# Out:
# (322, 13)

# %%
len(df[(df['Survived']== 0)&(df['Age']<40)])
# Out:
# 322

# %% [raw]
# 10 . from a  cabin column seperate text and numeric value .

# %%
import re
replace = re.compile("([a-zA-Z]+)")
df['string_cabin']  = df['Cabin'].str.extract("([a-zA-Z]+)")
df['number_cabin'] = df['Cabin'].str.replace("([a-zA-Z]+)",'')
# Out:
# C:\Users\VIJITK~1\AppData\Local\Temp/ipykernel_24140/2335221188.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['number_cabin'] = df['Cabin'].str.replace("([a-zA-Z]+)",'')

# %%
df['string_cabin']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin, Length: 891, dtype: object

# %%
df['number_cabin']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: number_cabin, Length: 891, dtype: object

# %% [raw]
# 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level

# %%
df1 = pd.read_csv('bank.csv',sep = ';')

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [raw]
# 1 . how many campaign available in this dataset

# %%
len(df1['campaign'].unique())
# Out:
# 32

# %% [raw]
# 2 . how many users do we have with housing and personal loan .

# %%
len(df1[(df1['housing'] == 'yes') & (df1['loan']=='yes')])
# Out:
# 406

# %% [raw]
# 3. how many person do we have whose age is 60+ .

# %%
len(df1[df1['age'] >= 60])
# Out:
# 174

# %% [raw]
# 4 . in which month we have trageted most of the customer

# %%
df1['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
df1.groupby('month').count()
# Out:
#         age   job  marital  education  default  balance  housing  loan  \
# month
# apr     293   293      293        293      293      293      293   293
# aug     633   633      633        633      633      633      633   633
# dec      20    20       20         20       20       20       20    20
# feb     222   222      222        222      222      222      222   222
# jan     148   148      148        148      148      148      148   148
# jul     706   706      706        706      706      706      706   706
# jun     531   531      531        531      531      531      531   531
# mar      49    49       49         49       49       49       49    49
# may    1398  1398     1398       1398     1398     1398     1398  1398
# nov     389   389      389        389      389      389      389   389
# oct      80    80       80         80       80       80       80    80
# sep      52    52       52         52       52       52       52    52
#
#        contact   day  duration  campaign  pdays  previous  poutcome     y
# month
# apr        293   293       293       293    293       293       293   293
# aug        633   633       633       633    633       633       633   633
# dec         20    20        20        20     20        20        20    20
# feb        222   222       222       222    222       222       222   222
# jan        148   148       148       148    148       148       148   148
# jul        706   706       706       706    706       706       706   706
# jun        531   531       531       531    531       531       531   531
# mar         49    49        49        49     49        49        49    49
# may       1398  1398      1398      1398   1398      1398      1398  1398
# nov        389   389       389       389    389       389       389   389
# oct         80    80        80        80     80        80        80    80
# sep         52    52        52        52     52        52        52    52

# %% [raw]
# 5 . which mode of call is giving you more result

# %%
df2 = df1[df1['y'] == 'yes']
df2['contact'].value_counts()
# Out:
# cellular     416
# unknown       61
# telephone     44
# Name: contact, dtype: int64

# %%
df_group=df1.groupby(['contact','y']).count()

# %%
df_group
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
#           yes    61    61     61        61        61     61        61
#
#                poutcome
# contact   y
# cellular  no       2480
#           yes       416
# telephone no        257
#           yes        44
# unknown   no       1263
#           yes        61

# %%
df_group.loc['cellular','yes'][0]
# Out:
# 416

# %% [raw]
# 6 . how many enterpeures do we have in this list

# %%
len(df1[df1['job']=='entrepreneur'])
# Out:
# 168

# %% [raw]
#  . how many customers do we have with negative balance

# %%
len(df1[df1['balance']<0])
# Out:
# 366

# %% [raw]
# 8. prepare a group of data based on education level

# %%
df1.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education']==i])

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4480   cellular   16   apr       743         1     -1         0  unknown   no
# 4485   cellular   11   may       238         2    361         5  failure   no
# 4486    unknown    9   may       514         1     -1         0  unknown   no
# 4499   cellular   21   nov       362         1     -1         0  unknown   no
# 4503   cellular   29   jul       816         6     -1         0  unknown  yes
#
# [678 rows x 17 columns]

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1     cellular   11   may       220         1    339         4  failure  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 10     unknown   20   may       273         1     -1         0  unknown  no
# 11    cellular   17   apr       113         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4514  cellular   20   apr        45         4    153         1  failure  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
#
# [2306 rows x 17 columns]

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 5     cellular   23   feb       141         2    176         3  failure  no
# 6     cellular   14   may       341         1    330         2    other  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4501  cellular   26   aug        63         4     -1         0  unknown  no
# 4506  cellular   29   aug        85         4     -1         0  unknown  no
# 4509  cellular   30   nov       210         3     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [1350 rows x 17 columns]

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 20     cellular   18   nov        96         2     -1         0  unknown   no
# 27    telephone   17   aug       119         1    105         2  failure   no
# 49     cellular   27   jan       181         1     92         1  success  yes
# 132     unknown   30   may        67         3     -1         0  unknown   no
# 133    cellular    8   may        85         1    168         2  failure   no
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4337  telephone   16   oct       434         1     57         1  failure  yes
# 4342  telephone   31   jul      1088        17     -1         0  unknown  yes
# 4428   cellular    2   feb       212         1    249         2    other   no
# 4471   cellular   21   nov       216         4     -1         0  unknown   no
# 4508    unknown   16   may       509         2     -1         0  unknown   no
#
# [187 rows x 17 columns]

# %%
f = open(b"C:\\Users\\vijit kumar\\Downloads\\12+ (2).docx",'r+')

# %%
f.read
# Out:
# <function TextIOWrapper.read(size=-1, /)>

# %%
f.readline()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\VIJITK~1\AppData\Local\Temp/ipykernel_19452/3005578867.py in <module>
# ----> 1 f.readline()
#
# ~\.conda\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 611: character maps to <undefined>

# %%
f.seek(0)
# Out:
# 0

# %%
# !pip install textract
# Out:
# Collecting textract
#   Downloading textract-1.6.4.tar.gz (17 kB)
# Collecting argcomplete~=1.10.0
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting docx2txt~=0.8
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
# Collecting EbookLib==0.*
#   Downloading EbookLib-0.17.1.tar.gz (111 kB)
# Collecting extract-msg<=0.29.*
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
# Collecting pdfminer.six==20191110
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
# Collecting python-pptx~=0.6.18
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
# Collecting xlrd~=1.2.0
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Requirement already satisfied: lxml in c:\users\vijit kumar\.conda\lib\site-packages (from EbookLib==0.*->textract) (4.6.3)
# Collecting pycryptodome
#   Downloading pycryptodome-3.14.1-cp35-abi3-win_amd64.whl (1.8 MB)
# Requirement already satisfied: sortedcontainers in c:\users\vijit kumar\.conda\lib\site-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\vijit kumar\.conda\lib\site-packages (from beautifulsoup4~=4.8.0->textract) (2.2.1)
# Requirement already satisfied: olefile>=0.46 in c:\users\vijit kumar\.conda\lib\site-packages (from extract-msg<=0.29.*->textract) (0.46)
# Collecting tzlocal>=2.1
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Collecting imapclient==2.1.0
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
# Collecting compressed-rtf>=1.0.6
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
# Collecting ebcdic>=1.1.1
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\vijit kumar\.conda\lib\site-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\vijit kumar\.conda\lib\site-packages (from python-pptx~=0.6.18->textract) (3.0.1)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: textract, EbookLib, docx2txt, compressed-rtf, python-pptx
#   Building wheel for textract (setup.py): started
#   Building wheel for textract (setup.py): finished with status 'done'
#   Created wheel for textract: filename=textract-1.6.4-py3-none-any.whl size=22888 sha256=ca5a49b2b25308add518411abb09ac14e64433dc0fce8f3b4b26d340817ba65e
#   Stored in directory: c:\users\vijit kumar\appdata\local\pip\cache\wheels\31\50\c6\acfae9490f182344f3a7a4561ddac71bc59903ed7d56f07a6c
#   Building wheel for EbookLib (setup.py): started
#   Building wheel for EbookLib (setup.py): finished with status 'done'
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38183 sha256=02ddf0a023c081bc60546182baf7d3ec3e70415ddaa2d54727bfb745b27c98b7
#   Stored in directory: c:\users\vijit kumar\appdata\local\pip\cache\wheels\b3\81\87\9b2b38976b783a8c2baffb72b320d2af59f8da80e6cb6410fd
#   Building wheel for docx2txt (setup.py): started
#   Building wheel for docx2txt (setup.py): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=584e67b3f8171ebda666f7325016d9696bfea233640dbbd9d862f791d260e2c0
#   Stored in directory: c:\users\vijit kumar\appdata\local\pip\cache\wheels\40\75\01\e6c444034338bde9c7947d3467807f889123465c2371e77418
#   Building wheel for compressed-rtf (setup.py): started
#   Building wheel for compressed-rtf (setup.py): finished with status 'done'
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6200 sha256=9c5521c8b690ca58aaae111a786852af99aefc75825240d66968a3900837a391
#   Stored in directory: c:\users\vijit kumar\appdata\local\pip\cache\wheels\e4\67\e4\ba2159853bdd0fe99330aa1e384915108143a5370686ea446f
#   Building wheel for python-pptx (setup.py): started
#   Building wheel for python-pptx (setup.py): finished with status 'done'
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470950 sha256=57ffb03f97393e73e244adda84b7583162dde8db0db6ccac881a471538f6b0b3
#   Stored in directory: c:\users\vijit kumar\appdata\local\pip\cache\wheels\0e\4a\ed\9653bc799915f52dce3f04d14946fbd85cce9c3cdedc9cfa71
# Successfully built textract EbookLib docx2txt compressed-rtf python-pptx
# Installing collected packages: tzdata, six, pytz-deprecation-shim, tzlocal, pycryptodome, imapclient, ebcdic, compressed-rtf, chardet, xlrd, SpeechRecognition, python-pptx, pdfminer.six, extract-msg, EbookLib, docx2txt, beautifulsoup4, argcomplete, textract
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.10.0
#     Uninstalling beautifulsoup4-4.10.0:
#       Successfully uninstalled beautifulsoup4-4.10.0
# Successfully installed EbookLib-0.17.1 SpeechRecognition-3.8.1 argcomplete-1.10.3 beautifulsoup4-4.8.2 chardet-3.0.4 compressed-rtf-1.0.6 docx2txt-0.8 ebcdic-1.1.1 extract-msg-0.28.7 imapclient-2.1.0 pdfminer.six-20191110 pycryptodome-3.14.1 python-pptx-0.6.21 pytz-deprecation-shim-0.1.0.post0 six-1.12.0 textract-1.6.4 tzdata-2021.5 tzlocal-4.1 xlrd-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.

# %%
import textract

# %%
text = textract.process('C:\\Users\\vijit kumar\\Downloads\\12+ (2) (1).docx')

# %%
text
# Out:
# b'---------------------------------------------------------------------------------------------------\n\n\t\t    \n\n\t\tProfessional Summary:                                       \n\n\t\t\n\n\tViji45@gmail.com\n\n\t\n\n\tAround 12+ Years of IT experience in PL/SQL, Mainframes and Data Science technologies in Retail, Banking and Healthcare domains\n\n\tAround 4+ years of experience as Data Scientist with proven expertise in Machine Learning Algorithms, Deep Learning concepts such as ANN, CNN, RNN and python with libraries such as SKLearn, NumPy, Pandas, Matplotlib, Keras and Tensor Flow.\n\n\tAround 1+ year of experience in Pentaho for building files via access to database.\n\n\tAround 8+ years of experience in Mainframes platform with expertise in COBOL, JCL, VSAM, SAS, DB2 in both development and Support roles as well as PL-SQL and Oracle Database\n\n\tStrong proficiency in application development & quality-driven methodologies.\n\n\tExpertise in full SDLC implementation as a key resource in requirement gathering, estimation, design, coding and testing in both Waterfall and Agile Methodology. \n\n\tInvolved in sprint planning, creation of user stories, assessment of story points, Agile retrospective meeting.\n\n\tExtensively used JIRA tool for tracking user stories and effort\n\n\tStrong Leadership skills and rated as a very capable resource in managing team effectively.\n\n\tExcellent communication and presentation skills, self-starter, quick learner & team         player\n\n\t\n\nTechnical Skill Set:\n\n\n\nProgramming Languages: \n\nPython, Machine Learning (NumPy, Pandas, Matplotlib), Deep Neural Networks (Keras, Tensor Flow), Convolutional Neural Networks, SKlearn Libraries, SPARK Framework, SCALA basics, COBOL, SAS, JCL, VSAM, SQL/PLSQL\n\n\n\nTOOLS: \n\nAnaconda, Jupiter Notebook, Pentaho, JIRA, GitHub, IBM Personal Communication tools like - IBM File Manager, CA-7, SDSF, SAR, IBM File manager, QMF, SPUFI, SUPERC, Endevor, Change Man, ITSM Change Management Tool, \n\n\n\nData Base:  DB2, ORACLE\n\n\n\nProfessional Work Experience:\n\n\n\nStarted working in JP Morgan Chase as Senior Application Lead Developer from Oct 2015 till date.\n\nWorked as Principle Software Engineer in TESCO HSC from February 2011 till Oct 2015.\n\nWorked as Software Engineer in Fidelity India Pvt Ltd from September 2010 till Feb 2011.\n\nWorked as a Lead coordinator in IBM India Pvt LTD from Sep 2009 till August 2010.\n\nWorked as Developer in IBM India Pvt Ltd from August 2006 Till August 2009.\n\n\t\n\n\tCertifications and Achievements:\n\n\t\n\nWon as a runner in ML Theme in TechGig competition.\n\nCompleted Data science masters in ACADGILD.\n\nIBM Certified DB2 Fundamentals.\n\nSAS certified base programmer.\n\nCertified PAHM (Professional Academy for Healthcare Management) in Year 2007.\n\nWellPoint Achievement award for outstanding performance in GL project.\n\nReceived Value award for smooth and successful closure for Christmas.\n\nInvolved in CMMI Level 5 recertification program as a Lead and participated in interview with CMMI.\n\n\t\n\n\tAssignment Summary:\n\n\n\n\n\nProject # 1\n\n\n\nProject Name\t: Loan Grader                                                             Role  : Data Scientist\n\nClient   \t: JPMC\n\nDuration         : Oct 2016 to Sept 2017\n\nEnvironment\t: Python, SKLearn Libraries, Data Visualisation Thru Matplotlib/Seaborn, Machine Learning Algorithms\n\n\n\nDescription: Predict the rating of all customers in order to decide whether he/she is a potential customer to be considered by taking the history of the transactional data which includes banking, card transactions, loans.\n\n\n\nResponsibilities:\n\nRequirement discussions with the clients and also coordinating with Operations team to      understand the manual work around done by the team.\n\nReview the estimates for work items, help the team with impact analysis and participate in estimation justification meetings with the clients.\n\nIdentifying the poi ...

# %%
s = str(text)

# %%
x = s.split('\n')

# %%
import re
l = []
def email(x):
    try:
        for i in x:
            p = '(\w+)@(\w+)\.(com)'
            r = re.search(p,i)
        l.append(r.group(0))
        return l
    except Exception as e:
        print(e)

# %%
email(x)
# Out:
# ['tViji45@gmail.com']
